# %% [markdown]
# Artigos pra ler: Student behaviour in unsuporvised online quizzzes : a closer look

# %% [raw]
# Coletor de atributos em cima dos logs do CodeBench

# %% [raw]
# Atributos coletados:
# DONE •attempts (M1): n de tentativas de submissao, independente se o codigo esta certo ou errado (AHADI; VIHAVAINEN; LISTER, 2016);
# • lloc (M4): media de numero de linhas logicas dos codigos submetidos, sem contabilizar importação de bibliotecas, comentários e linhas em branco (OTERO et al., 2016);
# • loc(M5):media de numero de linhas dos codigos submetidos(OTEROetal.,2016);
# • $$ system_access (M7): numero de acessos (logins) que cada aluno faz dentro do prazo de entrega de uma dada lista;
# • exam_grade_codebench (M8): nota na avaliacao realizada em cada sessao. (So vai ser usado nessa tabela)
# • delete_average (M10): media de caracteres apagados atraves do uso das teclas delete e backspace em cada lista de exercicios;
# • average_log_rows (M11): media do numero de linhas do log gerado por cada questao de uma dada lista de exercicios (CASTRO-WUNSCH; AHADI; PETERSEN, 2017; AHADI et al., 2015)4;
# • submission_per_exercise (M12): media de submissoes por exercicios, independente se o codigo estava certo ou errado.
# • sucess_average (M13): razao entre o numero de questoes corretamente avaliadas pelo numero de tentativas de submissao (AUVINEN, 2015; ESTEY; COADY, 2016);
# • test_average (M14): numero total de testes feitos durante as tentativas de solucionar todas as questões de uma lista dividido pelo numero total de questões da lista (ESTEY; COADY, 2016);
# • exercises_list_grade (M15): nota do aluno em cada lista de exercícios (AHADI; VIHAVAINEN; LISTER, 2016; CASTRO-WUNSCH; AHADI; PETERSEN, 2017; ESTEY; COADY, 2016);
# • exercises_list_grade_check_plagiarism (M16): nota do aluno em cada lista de exercícios, considerando apenas questões resolvidas que geraram no mínimo 50 linhas no log;
# • copy_paste_proportion (M17): proporção entre número de caracteres colados (com CTRL+V) e número caracteres digitados (MUNSON; ZITOVSKY, 2018);
# • sintaxe_error (M18): proporção entre o número total de submissões e o número total de submissões com erros de sintaxe (JADUD, 2006b; ESTEY; COADY, 2016; MUNSON; ZITOVSKY, 2018);
# IDE_usage (M19): tempo total (em minutos) que o aluno passa dentro do IDE tentando solucionar as questões de uma dada lista de exercícios, ou seja, digitando algo (AUVINEN, 2015; MUNSON; ZITOVSKY, 2018);
# • $$keystroke_latency (M20): velocidade de digitação de um dado aluno durante suas tentativas de solucionar as questões de uma dada lista de exercícios (LEINONEN et al., 2016);
# DONE • duration_of_exercices: diferença entre o tempo inicial e o tempo final
# • qnt_errors: quantidade de erros na submissao/execucao
# • had_syntax_error: binario se houve(1) ou nao(0) erro de sintaxe
# • qnt_blur: quantidade de vezes q houve um clique fora da IDE -posso fazer uma media de interacoes com mouse-
# • time_medio_ blur: tempo total da diferenca entre um blur e um focus dividido pelo tempo total do exercicio
# • average_interation_time: media de tempo de interacao usuario-sistema
# • (talvez) turno_realizado: turno do dia em que o exercicio foi terminado
# • $$hours_remaning_to_deadline: diferenca de horas desde o primeiro acesso ate o deadline do exercicio
# • n_acessos: quantidade de acessos em dias diferentes
# • media de exercicios por lab resolvidos (avg_participation) - somente a razao eh suficiente pra pesar o desempenho do aluno? -
# • (talvez) acumulado das razoes de exercicios
# • pesar os tipos erro (sintaxe e logica) e se o aluno colou associar a ele um valor menor

# %%
import re
import os
import math
import pandas as pd
import datetime

# %%
path = 'Dataset/2018-1/'

# %% [markdown]
# cat database/2432/399_1326.log

# %%
dictHorarios = {}
colunasTabela = {'Aluno':['00'],
    'Laboratorio':['00'],
    'Exercicio':['00'],
    'Horario inicial':['00'],
    'Horario final':['00'],
    'Tempo decorrido':['00']
}

df2 = pd.DataFrame(columns=['oi','sa'])
print(df2)
# Out:
# Empty DataFrame
# Columns: [oi, sa]
# Index: []

# %%
#Coleta a data inicial e final de cada exercicio junto com o seu horario
def coletaDatas(arquivo):
    horarios = []
    hBegin = -1
    hEnd = -1
    dataIni = -1
    dataFim = -1
    horaIni = -1
    horaFim = -1
    for linha in arquivo:
        busca = re.findall(r'\d{4}-\d{1,2}-\d{1,2} \d+:\d+:\d+\.\d+',linha)
        if(len(busca) > 0):
            horaIni = busca[0]
            horarios.append(horaIni)
    if(len(horarios)>0):
        hBegin = horarios[0]
        hEnd = horarios[-1]
    if(hBegin != -1):
        busquinha = re.findall(r'\d{4}-\d{1,2}-\d{1,2}',hBegin)
        if(len(busquinha) > 0):
            dataIni = busquinha[0]
        busquinha = re.findall(r'\d+:\d+:\d+\.\d+',hBegin)
        if(len(busquinha) > 0):
            horaIni = busquinha[0]
    if(hEnd != -1):
            busquinha = re.findall(r'\d{4}-\d{1,2}-\d{1,2}',hEnd)
            if(len(busquinha)>0):
                    dataFim = busquinha[0]
            busquinha = re.findall(r'\d+:\d+:\d+\.\d+',hEnd)
            if(len(busquinha) > 0):
                horaFim = busquinha[0]
    '''            
    print("data raw:")
    print(hBegin,hEnd)
    print(dataIni, dataFim)
    print("Datas")
    print(horaIni,horaFim)
    print("EOF")
    '''
    return horarios, dataIni, dataFim, horaIni, horaFim

# %%
#Calcula a quantidade de linhas de um arquivo de log
def qntd_linhas_log(arquivo):
    contador = 0
    paste = 0
    delete = 0
    for linha in arquivo.split("\n"):
        contador += 1
        busca = re.search(r'paste',linha)
        busca2 = re.search(r'delete',linha)
        busca3 = re.search(r'Backspace',linha)
        if(busca): paste += 1
        if(busca2): delete += 1
        if(busca3): delete += 1
    
    p1 = paste/contador
    p2 = delete/contador
    return contador,round(p1,2),round(p2,2)

# %%
#Calcula o tempo empenhado no exercicio
def tempoEmpenhado(data_ini, data_fim, hora_ini, hora_fim):
    s = '' + str(data_ini) + ' ' + str(hora_ini) 
    r = '' + str(data_fim) + ' ' +str(hora_fim)
    date1 = int(datetime.datetime.strptime(s, '%Y-%m-%d %H:%M:%S.%f').strftime("%s"))
    date2 = int(datetime.datetime.strptime(r, '%Y-%m-%d %H:%M:%S.%f').strftime("%s"))
    difdate = date2 - date1
    return difdate

# %%
#Calcula a quantidade de dias em que o mesmo exercicio foi resolvido
def n_acessosColetor(arquivo):
    primeiroAcesso = 1
    difdate = 0
    for linha in arquivo:
        busca = re.search(r'\d{4}-\d{1,2}-\d{1,2}',linha)
        if(busca):
            if(primeiroAcesso):
                dataIni = busca.group(0)
                primeiroAcesso = 0
            dataAtual = busca.group(0)
            #date1 = int(datetime.datetime.strptime(dataIni, '%Y-%m-%d').strftime("%d"))
            #date2 = int(datetime.datetime.strptime(dataAtual, '%Y-%m-%d').strftime("%d"))
            #difdate = date2 - date1
            start_date = datetime.datetime.strptime(dataIni, '%Y-%m-%d')
            end_date = datetime.datetime.strptime(dataAtual, '%Y-%m-%d')
            difdate = abs(end_date-start_date)
            difdate = difdate.days
            

            
    
    return difdate

# %% [markdown]
# Funcoes na pasta Executions

# %%
#Ve a quantidade de submissoes em um exercicio
def attemptsColetor(arquivo):
    contador = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'SUBMITION',linha)
        if(busca): contador += 1
    return contador

# %%
#Ve a quantidade de testes em um exercicio
def testColetor(arquivo):
    contador = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'TEST',linha)
        if(busca): contador += 1
    return contador

# %% [markdown]
# Funcoes na pasta Scores

# %%
#Ve a quantidade de exercicios em um laboratorio
def exercicios_no_lab(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'number of exercises: \d+',linha)
        if(busca): 
            busca2 = re.search(r'\d+',busca.group(0))
            return busca2.group(0)

# %%
#Ve a quantidade de exercicios respondidos corretamente em um laboratorio
def exer_certos_no_lab(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'correct: \d+',linha)
        if(busca): 
            busca2 = re.search(r'\d+',busca.group(0))
            return busca2.group(0)

# %%
#Nota final por laboratorio
def nota_lab(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'final score  \(0-10\): \d+\.\d+',linha)
        if(busca):
            busca2 = re.search(r'\d+\.\d+',busca.group(0))
            return busca2.group(0)

# %%
#Quantidade de linhas de um codigo
def qntd_linhas(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'\w*',linha)
        if(busca): qntd += 1
    return qntd

# %%
#Quantidade de linhas de um codigo sem comentarios etc
def qntd_linhas_filtrado(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'\S',linha)
        if(busca): 
            busca2 = re.search(r'^(?!#).*',busca.group(0))
            if(busca2): qntd += 1

    return qntd

# %%
def keystroke_latency(arquivo):
    for linha in arquivo.split("\n"):
        hora = re.search(r'\d{4}-\d{1,2}-\d{1,2}',linha)

# %% [raw]
# Main Function

# %%
#Definindo o DataFrame
colunas = ['Aluno','Lab','Exercicio','Duracao','Qntd_Linhas','Qntd_Linhas_Filtrado','Testes','Submissoes','N_Dias','PP_Paste','PP_Delete','Linhas_Log','Nota']
df = pd.DataFrame(columns = colunas)
print(df)
df = df[0:0]
# Out:
# Empty DataFrame
# Columns: [Aluno, Lab, Exercicio, Duracao, Qntd_Linhas, Qntd_Linhas_Filtrado, Testes, Submissoes, N_Dias, PP_Paste, PP_Delete, Linhas_Log, Nota]
# Index: []

# %%
#MAIN
for folder in os.listdir(path):
    if not folder.startswith('.'):
        
        directory = os.path.join(path,folder)+'/users/'
        classe = folder
        for aux in os.listdir(directory):
            print(directory,aux)
            #directory = os.path.join(directory,aux)
            #pastaLogs = directory + aux + '/codemirror'
            pastaLogs = os.path.join(directory,aux) + '/codemirror'
            #Trabalhando com o arquivo do logs de interacao
            aluno = aux
            for file in os.listdir(pastaLogs):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]
                    exercicio = buscaL[1]
                file = os.path.join(pastaLogs,file)
                arquivo = open(file,'r',encoding='ISO-8859-1')
                data = arquivo.read()
                dataSplitado = data.split("\n")
                #-/-
                #parte para coleta de horario
                vetHorarios, date_begin, date_end, hour_begin, hour_end = coletaDatas(dataSplitado)
                dictHorarios[str(exercicio)] = vetHorarios

                if(hour_begin != -1):
                    #calcula o tempo emepnhado
                    exr_duration = tempoEmpenhado(date_begin, date_end, hour_begin, hour_end)
                #Coleta numero de acessos
                n_acessos = n_acessosColetor(dataSplitado)
                if(n_acessos == 0): n_acessos = 1
                qt_linhas, pp_paste, pp_delete = qntd_linhas_log(data)
                df = df.append({'Aluno': aluno,'Lab' : laboratorio,'Exercicio' : exercicio,'Duracao':exr_duration
                                ,'Qntd_Linhas':0,'Qntd_Linhas_Filtrado':0,'Testes':0,'Submissoes':0,'N_Dias':n_acessos,
                                'PP_Paste':pp_paste,'PP_Delete':pp_delete,'Linhas_Log':qt_linhas,'Nota':0.0}, ignore_index=True)    


            #a partir de agora eu trabalho com outro tipo de arquivo para a coleta, o de tests e submissions
            pastaExecucoes = os.path.join(directory,aux) + '/executions'
            for file in os.listdir(pastaExecucoes):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]
                    exercicio = buscaL[1]  
                file = os.path.join(pastaExecucoes,file)
                arquivo = open(file,'r',encoding='ISO-8859-1')
                data = arquivo.read()
                #Quantidade de submissoes por exercicio
                attempts = attemptsColetor(data)

                #Quantidade de testes por exercicio
                tests = testColetor(data)
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Testes'] = tests
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Submissoes'] = attempts

            #Coletando atributos da pasta score 
            pastaScores = os.path.join(directory,aux) + '/grades'
            for file in os.listdir(pastaScores):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]  
                #file = os.path.join(pastaScores,file)
                #arquivo = open(file,'r',encoding='ISO-8859-1')
                #data = arquivo.read()
                #Quantidade de exercicios do laboratorio
                #qntd_exercicios = exercicios_no_lab(data)
                #Quantidade de exercicios do laboratorio respondidos corretamente
                #qntd_exer_corretos = exer_certos_no_lab(data)
                #Nota do lab
                #nota_do_lab = nota_lab((data))
                #if(nota_do_lab == None): nota_do_lab = 0
                #df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio),'Nota'] = float(nota_do_lab)
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio),'Nota'] = 0

            #Coletando atributos da pasta codes
            pastaCodigos = os.path.join(directory,aux) + '/codes'
            for file in os.listdir(pastaCodigos):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]
                    exercicio = buscaL[1]  
                file = os.path.join(pastaCodigos,file)
                arquivo = open(file,'r',encoding='ISO-8859-1')
                data = arquivo.read()
                #Quantidade de linhas de um codigo
                linhas_codigo = qntd_linhas(data)
                #Quantidade de linhas de um codigo sem comentarios, importacoes
                linhas_codigo_filtrado = qntd_linhas_filtrado(data)
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Qntd_Linhas'] = linhas_codigo
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Qntd_Linhas_Filtrado'] = linhas_codigo_filtrado
# Out:
# Dataset/2018-1/180/users/ 1168
# Dataset/2018-1/180/users/ 1502
# Dataset/2018-1/180/users/ 1591
# Dataset/2018-1/180/users/ 2182
# Dataset/2018-1/180/users/ 2306
# Dataset/2018-1/180/users/ 2495
# Dataset/2018-1/180/users/ 2535
# Dataset/2018-1/180/users/ 2613
# Dataset/2018-1/180/users/ 2639
# Dataset/2018-1/180/users/ 2869
# Dataset/2018-1/180/users/ 3031
# Dataset/2018-1/180/users/ 3222
# Dataset/2018-1/180/users/ 3223
# Dataset/2018-1/180/users/ 3224
# Dataset/2018-1/180/users/ 3225
# Dataset/2018-1/180/users/ 3226
# Dataset/2018-1/180/users/ 3227
# Dataset/2018-1/180/users/ 3228
# Dataset/2018-1/180/users/ 3229
# Dataset/2018-1/180/users/ 3230
# Dataset/2018-1/180/users/ 3231
# Dataset/2018-1/180/users/ 3232
# Dataset/2018-1/180/users/ 3233
# Dataset/2018-1/180/users/ 3234
# Dataset/2018-1/180/users/ 3235
# Dataset/2018-1/180/users/ 3236
# Dataset/2018-1/180/users/ 3237
# Dataset/2018-1/180/users/ 3238
# Dataset/2018-1/180/users/ 3239
# Dataset/2018-1/180/users/ 3240
# Dataset/2018-1/180/users/ 3241
# Dataset/2018-1/180/users/ 3242
# Dataset/2018-1/180/users/ 3243
# Dataset/2018-1/180/users/ 3244
# Dataset/2018-1/180/users/ 3245
# Dataset/2018-1/180/users/ 3246
# Dataset/2018-1/180/users/ 3247
# Dataset/2018-1/180/users/ 3248
# Dataset/2018-1/180/users/ 3265
# Dataset/2018-1/180/users/ 3273
# Dataset/2018-1/180/users/ 3274
# Dataset/2018-1/180/users/ 3275
# Dataset/2018-1/180/users/ 3276
# Dataset/2018-1/180/users/ 3277
# Dataset/2018-1/180/users/ 3278
# Dataset/2018-1/180/users/ 3279
# Dataset/2018-1/180/users/ 3280
# Dataset/2018-1/180/users/ 3404
# Dataset/2018-1/180/users/ 3446
# Dataset/2018-1/180/users/ 3447
# Dataset/2018-1/180/users/ 3448
# Dataset/2018-1/180/users/ 3503
# Dataset/2018-1/180/users/ 3504
# Dataset/2018-1/180/users/ 3633
# Dataset/2018-1/181/users/ 1085
# Dataset/2018-1/181/users/ 1168
# Dataset/2018-1/181/users/ 1456
# Dataset/2018-1/181/users/ 1571
# Dataset/2018-1/181/users/ 1683
# Dataset/2018-1/181/users/ 1770
# Dataset/2018-1/181/users/ 2198
# Dataset/2018-1/181/users/ 2371
# Dataset/2018-1/181/users/ 2372
# Dataset/2018-1/181/users/ 2377
# Dataset/2018-1/181/users/ 2390
# Dataset/2018-1/181/users/ 2445
# Dataset/2018-1/181/users/ 2535
# Dataset/2018-1/181/users/ 2596
# Dataset/2018-1/181/users/ 2646
# Dataset/2018-1/181/users/ 2829
# Dataset/2018-1/181/users/ 3044
# Dataset/2018-1/181/users/ 3045
# Dataset/2018-1/181/users/ 3046
# Dataset/2018-1/181/users/ 3047
# Dataset/2018-1/181/users/ 3048
# Dataset/2018-1/181/users/ 3049
# Dataset/2018-1/181/users/ 3050
# Dataset/2018-1/181/users/ 3051
# Dataset/2018-1/181/users/ 3052
# Dataset/2018-1/181/users/ 3053
# Dataset/2018-1/181/users/ 3054
# Dataset/2018-1/181/users/ 3055
# Dataset/2018-1/181/users/ 3056
# Dataset/2018-1/181/users/ 3057
# Dataset/2018-1/181/users/ 3058
# Dataset/2018-1/181/users/ 3059
# Dataset/2018-1/181/users/ 3060
# Dataset/2018-1/181/users/ 3061
# Dataset/2018-1/181/users/ 3062
# Dataset/2018-1/181/users/ 3063
# Dataset/2018-1/181/users/ 3064
# Dataset/2018-1/181/users/ 3065
# Dataset/2018-1/181/users/ 3066
# Dataset/2018-1/181/users/ 3067
# Dataset/2018-1/181/users/ 3068
# Dataset/2018-1/181/users/ 3069
# Dataset/2018-1/181/users/ 3070
# Dataset/2018-1/181/users/ 3071
# Dataset/2018-1/181/users/ 3072
# Dataset/2018-1/181/users/ 3073
# Dataset/2018-1/181/users/ 3255
# Dataset/2018-1/181/users/ 3258
# Dataset/2018-1/181/users/ 3259
# Dataset/2018-1/181/users/ 3260
# Dataset/2018-1/181/users/ 3399
# Dataset/2018-1/181/users/ 3400
# Dataset/2018-1/181/users/ 3401
# Dataset/2018-1/181/users/ 3410
# Dataset/2018-1/181/users/ 3478
# Dataset/2018-1/181/users/ 3486
# Dataset/2018-1/181/users/ 3624
# Dataset/2018-1/183/users/ 1222
# Dataset/2018-1/183/users/ 1604
# Dataset/2018-1/183/users/ 1900
# Dataset/2018-1/183/users/ 2170
# Dataset/2018-1/183/users/ 2184
# Dataset/2018-1/183/users/ 2362
# Dataset/2018-1/183/users/ 2363
# Dataset/2018-1/183/users/ 2490
# Dataset/2018-1/183/users/ 2497
# Dataset/2018-1/183/users/ 2550
# Dataset/2018-1/183/users/ 2636
# Dataset/2018-1/183/users/ 2643
# Dataset/2018-1/183/users/ 2947
# Dataset/2018-1/183/users/ 2960
# Dataset/2018-1/183/users/ 3011
# Dataset/2018-1/183/users/ 3366
# Dataset/2018-1/183/users/ 3367
# Dataset/2018-1/183/users/ 3368
# Dataset/2018-1/183/users/ 3369
# Dataset/2018-1/183/users/ 3370
# Dataset/2018-1/183/users/ 3371
# Dataset/2018-1/183/users/ 3372
# Dataset/2018-1/183/users/ 3373
# Dataset/2018-1/183/users/ 3374
# Dataset/2018-1/183/users/ 3375
# Dataset/2018-1/183/users/ 3376
# Dataset/2018-1/183/users/ 3377
# Dataset/2018-1/183/users/ 3378
# Dataset/2018-1/183/users/ 3379
# Dataset/2018-1/183/users/ 3380
# Dataset/2018-1/183/users/ 3381
# Dataset/2018-1/183/users/ 3383
# Dataset/2018-1/183/users/ 3384
# Dataset/2018-1/183/users/ 3385
# Dataset/2018-1/183/users/ 3386
# Dataset/2018-1/183/users/ 3387
# Dataset/2018-1/183/users/ 3388
# Dataset/2018-1/183/users/ 3389
# Dataset/2018-1/183/users/ 3390
# Dataset/2018-1/183/users/ 3391
# Dataset/2018-1/183/users/ 3392
# Dataset/2018-1/183/users/ 3393
# Dataset/2018-1/183/users/ 3394
# Dataset/2018-1/183/users/ 3395
# Dataset/2018-1/183/users/ 3396
# Dataset/2018-1/183/users/ 3480
# Dataset/2018-1/183/users/ 3481
# Dataset/2018-1/183/users/ 3482
# Dataset/2018-1/183/users/ 3483
# Dataset/2018-1/183/users/ 3484
# Dataset/2018-1/183/users/ 3520
# Dataset/2018-1/183/users/ 3544
# Dataset/2018-1/183/users/ 3551
# Dataset/2018-1/183/users/ 3555
# Dataset/2018-1/183/users/ 3558
# Dataset/2018-1/185/users/ 1168
# Dataset/2018-1/185/users/ 1206
# Dataset/2018-1/185/users/ 1599
# Dataset/2018-1/185/users/ 2006
# Dataset/2018-1/185/users/ 2013
# Dataset/2018-1/185/users/ 2139
# Dataset/2018-1/185/users/ 2143
# Dataset/2018-1/185/users/ 2146
# Dataset/2018-1/185/users/ 2148
# Dataset/2018-1/185/users/ 2149
# Dataset/2018-1/185/users/ 2151
# Dataset/2018-1/185/users/ 2154
# Dataset/2018-1/185/users/ 2195
# Dataset/2018-1/185/users/ 2348
# Dataset/2018-1/185/users/ 2535
# Dataset/2018-1/185/users/ 2636
# Dataset/2018-1/185/users/ 2880
# Dataset/2018-1/185/users/ 2921
# Dataset/2018-1/185/users/ 2968
# Dataset/2018-1/185/users/ 2975
# Dataset/2018-1/185/users/ 3025
# Dataset/2018-1/185/users/ 3332
# Dataset/2018-1/185/users/ 3333
# Dataset/2018-1/185/users/ 3334
# Dataset/2018-1/185/users/ 3335
# Dataset/2018-1/185/users/ 3336
# Dataset/2018-1/185/users/ 3337
# Dataset/2018-1/185/users/ 3338
# Dataset/2018-1/185/users/ 3339
# Dataset/2018-1/185/users/ 3340
# Dataset/2018-1/185/users/ 3341
# Dataset/2018-1/185/users/ 3342
# Dataset/2018-1/185/users/ 3343
# Dataset/2018-1/185/users/ 3344
# Dataset/2018-1/185/users/ 3345
# Dataset/2018-1/185/users/ 3346
# Dataset/2018-1/185/users/ 3347
# Dataset/2018-1/185/users/ 3348
# Dataset/2018-1/185/users/ 3349
# Dataset/2018-1/185/users/ 3350
# Dataset/2018-1/185/users/ 3351
# Dataset/2018-1/185/users/ 3352
# Dataset/2018-1/185/users/ 3353
# Dataset/2018-1/185/users/ 3354
# Dataset/2018-1/185/users/ 3355
# Dataset/2018-1/185/users/ 3356
# Dataset/2018-1/185/users/ 3357
# Dataset/2018-1/185/users/ 3358
# Dataset/2018-1/185/users/ 3359
# Dataset/2018-1/185/users/ 3360
# Dataset/2018-1/185/users/ 3361
# Dataset/2018-1/185/users/ 3362
# Dataset/2018-1/185/users/ 3363
# Dataset/2018-1/185/users/ 3409
# Dataset/2018-1/185/users/ 3423
# Dataset/2018-1/185/users/ 3424
# Dataset/2018-1/185/users/ 3425
# Dataset/2018-1/185/users/ 3426
# Dataset/2018-1/185/users/ 3427
# Dataset/2018-1/185/users/ 3428
# Dataset/2018-1/185/users/ 3429
# Dataset/2018-1/185/users/ 3518
# Dataset/2018-1/185/users/ 3633
# Dataset/2018-1/186/users/ 1330
# Dataset/2018-1/186/users/ 1464
# Dataset/2018-1/186/users/ 2224
# Dataset/2018-1/186/users/ 3107
# Dataset/2018-1/186/users/ 3111
# Dataset/2018-1/186/users/ 3112
# Dataset/2018-1/186/users/ 3113
# Dataset/2018-1/186/users/ 3114
# Dataset/2018-1/186/users/ 3115
# Dataset/2018-1/186/users/ 3116
# Dataset/2018-1/186/users/ 3117
# Dataset/2018-1/186/users/ 3119
# Dataset/2018-1/186/users/ 3120
# Dataset/2018-1/186/users/ 3121
# Dataset/2018-1/186/users/ 3122
# Dataset/2018-1/186/users/ 3124
# Dataset/2018-1/186/users/ 3125
# Dataset/2018-1/186/users/ 3126
# Dataset/2018-1/186/users/ 3127
# Dataset/2018-1/186/users/ 3128
# Dataset/2018-1/186/users/ 3129
# Dataset/2018-1/186/users/ 3130
# Dataset/2018-1/186/users/ 3131
# Dataset/2018-1/186/users/ 3132
# Dataset/2018-1/186/users/ 3133
# Dataset/2018-1/186/users/ 3134
# Dataset/2018-1/186/users/ 3135
# Dataset/2018-1/186/users/ 3136
# Dataset/2018-1/186/users/ 3137
# Dataset/2018-1/186/users/ 3138
# Dataset/2018-1/186/users/ 3139
# Dataset/2018-1/186/users/ 3140
# Dataset/2018-1/186/users/ 3141
# Dataset/2018-1/186/users/ 3142
# Dataset/2018-1/186/users/ 3143
# Dataset/2018-1/186/users/ 3144
# Dataset/2018-1/186/users/ 3153
# Dataset/2018-1/186/users/ 3257
# Dataset/2018-1/186/users/ 3263
# Dataset/2018-1/186/users/ 3264
# Dataset/2018-1/186/users/ 3266
# Dataset/2018-1/186/users/ 3302
# Dataset/2018-1/186/users/ 3451
# Dataset/2018-1/186/users/ 3456
# Dataset/2018-1/186/users/ 3495
# Dataset/2018-1/186/users/ 3506
# Dataset/2018-1/186/users/ 3570
# Dataset/2018-1/186/users/ 3642
# Dataset/2018-1/187/users/ 1543
# Dataset/2018-1/187/users/ 1913
# Dataset/2018-1/187/users/ 2300
# Dataset/2018-1/187/users/ 2409
# Dataset/2018-1/187/users/ 2445
# Dataset/2018-1/187/users/ 2535
# Dataset/2018-1/187/users/ 2978
# Dataset/2018-1/187/users/ 3145
# Dataset/2018-1/187/users/ 3146
# Dataset/2018-1/187/users/ 3147
# Dataset/2018-1/187/users/ 3148
# Dataset/2018-1/187/users/ 3149
# Dataset/2018-1/187/users/ 3150
# Dataset/2018-1/187/users/ 3151
# Dataset/2018-1/187/users/ 3153
# Dataset/2018-1/187/users/ 3155
# Dataset/2018-1/187/users/ 3188
# Dataset/2018-1/187/users/ 3190
# Dataset/2018-1/187/users/ 3191
# Dataset/2018-1/187/users/ 3192
# Dataset/2018-1/187/users/ 3193
# Dataset/2018-1/187/users/ 3194
# Dataset/2018-1/187/users/ 3195
# Dataset/2018-1/187/users/ 3196
# Dataset/2018-1/187/users/ 3197
# Dataset/2018-1/187/users/ 3198
# Dataset/2018-1/187/users/ 3199
# Dataset/2018-1/187/users/ 3200
# Dataset/2018-1/187/users/ 3201
# Dataset/2018-1/187/users/ 3202
# Dataset/2018-1/187/users/ 3203
# Dataset/2018-1/187/users/ 3204
# Dataset/2018-1/187/users/ 3205
# Dataset/2018-1/187/users/ 3207
# Dataset/2018-1/187/users/ 3208
# Dataset/2018-1/187/users/ 3209
# Dataset/2018-1/187/users/ 3210
# Dataset/2018-1/187/users/ 3211
# Dataset/2018-1/187/users/ 3212
# Dataset/2018-1/187/users/ 3213
# Dataset/2018-1/187/users/ 3214
# Dataset/2018-1/187/users/ 3215
# Dataset/2018-1/187/users/ 3216
# Dataset/2018-1/187/users/ 3217
# Dataset/2018-1/187/users/ 3218
# Dataset/2018-1/187/users/ 3219
# Dataset/2018-1/187/users/ 3221
# Dataset/2018-1/187/users/ 3257
# Dataset/2018-1/187/users/ 3268
# Dataset/2018-1/187/users/ 3410
# Dataset/2018-1/187/users/ 3441
# Dataset/2018-1/187/users/ 3443
# Dataset/2018-1/187/users/ 3449
# Dataset/2018-1/187/users/ 3499
# Dataset/2018-1/187/users/ 3502
# Dataset/2018-1/187/users/ 3531
# Dataset/2018-1/187/users/ 3533
# Dataset/2018-1/187/users/ 3571
# Dataset/2018-1/187/users/ 3573
# Dataset/2018-1/188/users/ 1373
# Dataset/2018-1/188/users/ 1378
# Dataset/2018-1/188/users/ 2445
# Dataset/2018-1/188/users/ 2636
# Dataset/2018-1/188/users/ 3153
# Dataset/2018-1/188/users/ 3156
# Dataset/2018-1/188/users/ 3157
# Dataset/2018-1/188/users/ 3158
# Dataset/2018-1/188/users/ 3159
# Dataset/2018-1/188/users/ 3160
# Dataset/2018-1/188/users/ 3161
# Dataset/2018-1/188/users/ 3162
# Dataset/2018-1/188/users/ 3163
# Dataset/2018-1/188/users/ 3164
# Dataset/2018-1/188/users/ 3165
# Dataset/2018-1/188/users/ 3166
# Dataset/2018-1/188/users/ 3167
# Dataset/2018-1/188/users/ 3168
# Dataset/2018-1/188/users/ 3169
# Dataset/2018-1/188/users/ 3170
# Dataset/2018-1/188/users/ 3171
# Dataset/2018-1/188/users/ 3172
# Dataset/2018-1/188/users/ 3173
# Dataset/2018-1/188/users/ 3174
# Dataset/2018-1/188/users/ 3175
# Dataset/2018-1/188/users/ 3176
# Dataset/2018-1/188/users/ 3177
# Dataset/2018-1/188/users/ 3178
# Dataset/2018-1/188/users/ 3179
# Dataset/2018-1/188/users/ 3180
# Dataset/2018-1/188/users/ 3181
# Dataset/2018-1/188/users/ 3182
# Dataset/2018-1/188/users/ 3183
# Dataset/2018-1/188/users/ 3184
# Dataset/2018-1/188/users/ 3185
# Dataset/2018-1/188/users/ 3186
# Dataset/2018-1/188/users/ 3187
# Dataset/2018-1/188/users/ 3189
# Dataset/2018-1/188/users/ 3267
# Dataset/2018-1/188/users/ 3269
# Dataset/2018-1/188/users/ 3270
# Dataset/2018-1/188/users/ 3271
# Dataset/2018-1/188/users/ 3439
# Dataset/2018-1/188/users/ 3440
# Dataset/2018-1/188/users/ 3442
# Dataset/2018-1/188/users/ 3444
# Dataset/2018-1/188/users/ 3485
# Dataset/2018-1/188/users/ 3497
# Dataset/2018-1/188/users/ 3498
# Dataset/2018-1/188/users/ 3532
# Dataset/2018-1/189/users/ 1163
# Dataset/2018-1/189/users/ 1177
# Dataset/2018-1/189/users/ 1985
# Dataset/2018-1/189/users/ 2344
# Dataset/2018-1/189/users/ 2445
# Dataset/2018-1/189/users/ 3304
# Dataset/2018-1/189/users/ 3305
# Dataset/2018-1/189/users/ 3306
# Dataset/2018-1/189/users/ 3307
# Dataset/2018-1/189/users/ 3308
# Dataset/2018-1/189/users/ 3309
# Dataset/2018-1/189/users/ 3310
# Dataset/2018-1/189/users/ 3311
# Dataset/2018-1/189/users/ 3312
# Dataset/2018-1/189/users/ 3313
# Dataset/2018-1/189/users/ 3314
# Dataset/2018-1/189/users/ 3315
# Dataset/2018-1/189/users/ 3316
# Dataset/2018-1/189/users/ 3317
# Dataset/2018-1/189/users/ 3318
# Dataset/2018-1/189/users/ 3319
# Dataset/2018-1/189/users/ 3320
# Dataset/2018-1/189/users/ 3321
# Dataset/2018-1/189/users/ 3322
# Dataset/2018-1/189/users/ 3323
# Dataset/2018-1/189/users/ 3324
# Dataset/2018-1/189/users/ 3325
# Dataset/2018-1/189/users/ 3326
# Dataset/2018-1/189/users/ 3327
# Dataset/2018-1/189/users/ 3328
# Dataset/2018-1/189/users/ 3329
# Dataset/2018-1/189/users/ 3330
# Dataset/2018-1/189/users/ 3331
# Dataset/2018-1/189/users/ 3397
# Dataset/2018-1/189/users/ 3417
# Dataset/2018-1/189/users/ 3418
# Dataset/2018-1/189/users/ 3419
# Dataset/2018-1/189/users/ 3421
# Dataset/2018-1/189/users/ 3476
# Dataset/2018-1/189/users/ 3477
# Dataset/2018-1/189/users/ 3478
# Dataset/2018-1/189/users/ 3508
# Dataset/2018-1/189/users/ 3509
# Dataset/2018-1/189/users/ 3510
# Dataset/2018-1/189/users/ 3511
# Dataset/2018-1/189/users/ 3512
# Dataset/2018-1/189/users/ 3538
# Dataset/2018-1/189/users/ 3543
# Dataset/2018-1/189/users/ 3561
# Dataset/2018-1/189/users/ 3634
# Dataset/2018-1/190/users/ 1719
# Dataset/2018-1/190/users/ 2125
# Dataset/2018-1/190/users/ 2132
# Dataset/2018-1/190/users/ 2300
# Dataset/2018-1/190/users/ 2409
# Dataset/2018-1/190/users/ 2646
# Dataset/2018-1/190/users/ 2763
# Dataset/2018-1/190/users/ 3030
# Dataset/2018-1/190/users/ 3039
# Dataset/2018-1/190/users/ 3075
# Dataset/2018-1/190/users/ 3076
# Dataset/2018-1/190/users/ 3077
# Dataset/2018-1/190/users/ 3078
# Dataset/2018-1/190/users/ 3079
# Dataset/2018-1/190/users/ 3080
# Dataset/2018-1/190/users/ 3081
# Dataset/2018-1/190/users/ 3082
# Dataset/2018-1/190/users/ 3083
# Dataset/2018-1/190/users/ 3084
# Dataset/2018-1/190/users/ 3085
# Dataset/2018-1/190/users/ 3086
# Dataset/2018-1/190/users/ 3087
# Dataset/2018-1/190/users/ 3088
# Dataset/2018-1/190/users/ 3089
# Dataset/2018-1/190/users/ 3090
# Dataset/2018-1/190/users/ 3091
# Dataset/2018-1/190/users/ 3092
# Dataset/2018-1/190/users/ 3093
# Dataset/2018-1/190/users/ 3094
# Dataset/2018-1/190/users/ 3095
# Dataset/2018-1/190/users/ 3096
# Dataset/2018-1/190/users/ 3097
# Dataset/2018-1/190/users/ 3098
# Dataset/2018-1/190/users/ 3100
# Dataset/2018-1/190/users/ 3101
# Dataset/2018-1/190/users/ 3102
# Dataset/2018-1/190/users/ 3103
# Dataset/2018-1/190/users/ 3104
# Dataset/2018-1/190/users/ 3105
# Dataset/2018-1/190/users/ 3106
# Dataset/2018-1/190/users/ 3190
# Dataset/2018-1/190/users/ 3321
# Dataset/2018-1/190/users/ 3434
# Dataset/2018-1/190/users/ 3435
# Dataset/2018-1/190/users/ 3462
# Dataset/2018-1/190/users/ 3465
# Dataset/2018-1/190/users/ 3488
# Dataset/2018-1/190/users/ 3489
# Dataset/2018-1/190/users/ 3522
# Dataset/2018-1/190/users/ 3569

# %%
print("aluno:",aluno)
print("Dia inicio:",date_begin, "Dia fim:",date_end, "Hora inicio:",hour_begin,"Hora fim:", hour_end)
print("Numero de dias empenhados durante exercicio:",n_acessos)
print("Tempo empenhado na atividade em segundos:",exr_duration)
print("Numero do lab:",laboratorio,"exercicio:",exercicio,"submissoes:",attempts,"testes:",tests)
print("Total de exercicios:",qntd_exercicios,"Total respondido:",qntd_exer_corretos,"nota:",nota_do_lab)
print("Quantidade de linhas de codigo:",linhas_codigo, "Quantidade de linhas de codigo sem comentarios/importacoes:",linhas_codigo_filtrado)
# Out:
# aluno: 3569
# Dia inicio: 2018-4-17 Dia fim: 2018-4-17 Hora inicio: 10:46:13.287 Hora fim: 10:47:17.947
# Numero de dias empenhados durante exercicio: 1
# Tempo empenhado na atividade em segundos: 64
# Numero do lab: 1030 exercicio: 835 submissoes: 0 testes: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b78afb5146fc> in <module>()
#       4 print("Tempo empenhado na atividade em segundos:",exr_duration)
#       5 print("Numero do lab:",laboratorio,"exercicio:",exercicio,"submissoes:",attempts,"testes:",tests)
# ----> 6 print("Total de exercicios:",qntd_exercicios,"Total respondido:",qntd_exer_corretos,"nota:",nota_do_lab)
#       7 print("Quantidade de linhas de codigo:",linhas_codigo, "Quantidade de linhas de codigo sem comentarios/importacoes:",linhas_codigo_filtrado)
#
# NameError: name 'qntd_exercicios' is not defined

# %%
df['Aluno'] = df['Aluno'].astype(int)
df['Lab'] = df['Lab'].astype(int)
df['Duracao'] = df['Duracao'].astype(int)
df['Qntd_Linhas'] = df['Qntd_Linhas'].astype(int)
df['Qntd_Linhas_Filtrado'] = df['Qntd_Linhas_Filtrado'].astype(int)
df['Testes'] = df['Testes'].astype(int)
df['Submissoes'] = df['Submissoes'].astype(int)
df['N_Dias'] = df['N_Dias'].astype(int)
df['PP_Paste'] = df['PP_Paste'].astype(float)
df['PP_Delete'] = df['PP_Delete'].astype(float)
df['Linhas_Log'] = df['Linhas_Log'].astype(int)
df['Nota'] = df['Nota'].astype(float)

# %%
#Porcentagem de exercicios corretos/ total execicios por lab

# %%
agrupado =  df.groupby(['Aluno','Lab'],as_index=False).agg({'Duracao': 'sum', 'Qntd_Linhas': 'sum', 'Qntd_Linhas_Filtrado': 'sum'
                                             , 'Testes': 'sum', 'Submissoes': 'sum', 'PP_Paste': 'sum'
                                             , 'PP_Delete': 'sum', 'Linhas_Log': 'sum', 'Nota':'mean'})

# %%
agrupado
# Out:
#       Aluno   Lab  PP_Delete  Duracao  PP_Paste  Qntd_Linhas  Linhas_Log  \
# 0      1085  1031       0.53       80      0.00           25          19
# 1      1085  1083       0.34      296      0.01           24         372
# 2      1085  1118       0.69     3825      0.01          112        3484
# 3      1085  1265       0.30     1864      0.00           32         991
# 4      1163  1012       3.03   772009      0.10           35        1159
# 5      1163  1029       2.54  5881135      0.04          128        4996
# 6      1163  1051       2.73   616820      0.05          109        5529
# 7      1163  1052       0.47     1089      0.01           25         900
# 8      1163  1084       2.04  1665611      0.12          145        4158
# 9      1163  1089       0.14   409784      0.55           73          80
# 10     1163  1106       0.47     1889      0.02           35        1481
# 11     1163  1129       1.78   998318      0.40          307        9574
# 12     1163  1130       0.43   239567      0.01           30        2911
# 13     1163  1152       0.54     2657      0.01           71        2674
# 14     1163  1155       2.21  1542892      0.19          175        5773
# 15     1163  1182       0.74    11244      0.01           39        4812
# 16     1163  1194       1.52   276253      0.07          187        6501
# 17     1163  1220       0.72    12154      0.01           42        3642
# 18     1163  1228       1.53     5871      0.03          169        3391
# 19     1163  1230       0.19   170687      0.56           56         496
# 20     1163  1255       0.67     9257      0.01           46        2849
# 21     1163  1273       1.56  1812766      0.62          206        2499
# 22     1163  1302       0.71     9061      0.01           39        3429
# 23     1168  1018       0.11   928164      0.01            6          94
# 24     1168  1021       0.38      337      0.05            4         115
# 25     1168  1031       0.00       19      0.00            2          37
# 26     1177  1012       2.74  4422953      0.12           39        1435
# 27     1177  1029       3.61  2258304      0.03          177       11076
# 28     1177  1051       2.64  4104644      0.02          169        9304
# 29     1177  1052       0.60     2295      0.00           34        1038
# ...     ...   ...        ...      ...       ...          ...         ...
# 6679   3570  1072       2.27    26043      0.00          144        7334
# 6680   3570  1073       0.48     2118      0.02           63        1658
# 6681   3570  1097       0.60     4296      0.00           37        1583
# 6682   3570  1120       2.01   211328      0.00          321       21730
# 6683   3570  1132       0.35  3143972      0.00           53        2000
# 6684   3570  1147       0.31     1909      0.00           64        2240
# 6685   3570  1158       1.87    10944      0.01          182        3829
# 6686   3570  1175       0.60     3840      0.00           71        2466
# 6687   3570  1187       0.44     4497      0.00           44        2146
# 6688   3570  1199       2.54   533667      0.00          179       13020
# 6689   3570  1215       0.06      566      0.00           15         341
# 6690   3570  1232       0.34     8276      0.00           47        1663
# 6691   3570  1246       1.91   123629      0.01          180        6997
# 6692   3570  1266       2.02  1090818      0.01          273       12278
# 6693   3570  1286       1.62    61799      0.00           94        5638
# 6694   3570  1293       0.28     1041      0.00           32        1136
# 6695   3571  1019       0.00      217      1.92           35         106
# 6696   3571  1038       0.12        6      0.00           17           8
# 6697   3571  1159       0.93   850341      0.19           61        3007
# 6698   3573  1019       2.92    26170      0.01           74        2808
# 6699   3573  1038       0.00     2093      0.00           46          59
# 6700   3624  1123       0.00      187      0.00            3          18
# 6701   3624  1172       0.64    47056      0.00           63        4580
# 6702   3624  1212       0.58     7088      0.10           96       10008
# 6703   3624  1245       0.19     2585      0.00           29        1933
# 6704   3633  1201       1.43    88671      0.05          135        4177
# 6705   3633  1238       1.35    31364      0.11          128        4921
# 6706   3633  1289       1.50   122305      0.07          196        3747
# 6707   3634  1204       0.22     3609      0.02            9        1358
# 6708   3642  1286       0.10      246      0.06           10         196
#
#       Qntd_Linhas_Filtrado  Nota  Submissoes  Testes
# 0                        9   0.0           0       1
# 1                       11   0.0           4      12
# 2                       80   0.0          23      82
# 3                       20   0.0          17      42
# 4                       29   0.0          34      17
# 5                       74   0.0          34      77
# 6                       82   0.0          32     158
# 7                       17   0.0           3       9
# 8                       86   0.0          69     133
# 9                       50   0.0           8      20
# 10                      29   0.0           3      26
# 11                     263   0.0         130     288
# 12                      26   0.0           9      32
# 13                      61   0.0           5      31
# 14                     116   0.0          33      70
# 15                      28   0.0          43     203
# 16                     158   0.0          58     151
# 17                      32   0.0          94     209
# 18                     115   0.0          18      51
# 19                      53   0.0           6      21
# 20                      38   0.0           7      54
# 21                     161   0.0          17      53
# 22                      28   0.0          15     132
# 23                       6   0.0           5       4
# 24                       4   0.0           5       9
# 25                       2   0.0           0       0
# 26                      29   0.0          44      42
# 27                      76   0.0         104     157
# 28                      84   0.0          49     372
# 29                      14   0.0           3      39
# ...                    ...   ...         ...     ...
# 6679                    86   0.0          31     137
# 6680                    51   0.0           7      28
# 6681                    31   0.0           5      27
# 6682                   261   0.0          47     237
# 6683                    48   0.0           4      16
# 6684                    61   0.0           4      17
# 6685                   127   0.0          13      71
# 6686                    61   0.0           4      30
# 6687                    38   0.0           3      28
# 6688                   162   0.0          38     249
# 6689                    14   0.0           1       4
# 6690                    46   0.0           8      21
# 6691                   137   0.0          13      96
# 6692                   197   0.0          62     170
# 6693                    83   0.0          24     102
# 6694                    30   0.0           5      10
# 6695                    27   0.0          14      14
# 6696                     6   0.0           0       1
# 6697                    39   0.0          26     163
# 6698                    49   0.0          23      65
# 6699                    15   0.0           0       2
# 6700                     0   0.0           0       0
# 6701                    55   0.0           2      71
# 6702                    71   0.0           6      97
# 6703                    25   0.0           0      24
# 6704                    92   0.0          72     272
# 6705                   112   0.0          31     159
# 6706                   124   0.0          18     128
# 6707                     8   0.0          24      68
# 6708                     8   0.0           4      12
#
# [6709 rows x 11 columns]

# %%
agrupadoMedia = df.groupby(['Aluno','Lab'],as_index=False).agg({'Duracao': 'mean', 'Qntd_Linhas': 'mean', 'Qntd_Linhas_Filtrado': 'mean'
                                             , 'Testes': 'mean', 'Submissoes': 'mean', 'PP_Paste': 'mean'
                                             , 'PP_Delete': 'mean', 'Linhas_Log': 'mean', 'Nota':'mean'})

# %% [markdown]
# print(agrupadoMedia)

# %%
agrupadoMedia
# Out:
#       Aluno   Lab  PP_Delete       Duracao  PP_Paste  Qntd_Linhas  \
# 0      1085  1031   0.530000  8.000000e+01  0.000000    25.000000
# 1      1085  1083   0.170000  1.480000e+02  0.005000    12.000000
# 2      1085  1118   0.172500  9.562500e+02  0.002500    28.000000
# 3      1085  1265   0.300000  1.864000e+03  0.000000    32.000000
# 4      1163  1012   0.216429  5.514350e+04  0.007143     2.500000
# 5      1163  1029   0.211667  4.900946e+05  0.003333    10.666667
# 6      1163  1051   0.227500  5.140167e+04  0.004167     9.083333
# 7      1163  1052   0.156667  3.630000e+02  0.003333     8.333333
# 8      1163  1084   0.204000  1.665611e+05  0.012000    14.500000
# 9      1163  1089   0.023333  6.829733e+04  0.091667    12.166667
# 10     1163  1106   0.156667  6.296667e+02  0.006667    11.666667
# 11     1163  1129   0.148333  8.319317e+04  0.033333    25.583333
# 12     1163  1130   0.215000  1.197835e+05  0.005000    15.000000
# 13     1163  1152   0.180000  8.856667e+02  0.003333    23.666667
# 14     1163  1155   0.184167  1.285743e+05  0.015833    14.583333
# 15     1163  1182   0.246667  3.748000e+03  0.003333    13.000000
# 16     1163  1194   0.126667  2.302108e+04  0.005833    15.583333
# 17     1163  1220   0.240000  4.051333e+03  0.003333    14.000000
# 18     1163  1228   0.139091  5.337273e+02  0.002727    15.363636
# 19     1163  1230   0.038000  3.413740e+04  0.112000    11.200000
# 20     1163  1255   0.223333  3.085667e+03  0.003333    15.333333
# 21     1163  1273   0.130000  1.510638e+05  0.051667    17.166667
# 22     1163  1302   0.236667  3.020333e+03  0.003333    13.000000
# 23     1168  1018   0.055000  4.640820e+05  0.005000     3.000000
# 24     1168  1021   0.095000  8.425000e+01  0.012500     1.000000
# 25     1168  1031   0.000000  1.900000e+01  0.000000     2.000000
# 26     1177  1012   0.195714  3.159252e+05  0.008571     2.785714
# 27     1177  1029   0.300833  1.881920e+05  0.002500    14.750000
# 28     1177  1051   0.220000  3.420537e+05  0.001667    14.083333
# 29     1177  1052   0.200000  7.650000e+02  0.000000    11.333333
# ...     ...   ...        ...           ...       ...          ...
# 6679   3570  1072   0.227000  2.604300e+03  0.000000    14.400000
# 6680   3570  1073   0.080000  3.530000e+02  0.003333    10.500000
# 6681   3570  1097   0.200000  1.432000e+03  0.000000    12.333333
# 6682   3570  1120   0.167500  1.761067e+04  0.000000    26.750000
# 6683   3570  1132   0.116667  1.047991e+06  0.000000    17.666667
# 6684   3570  1147   0.103333  6.363333e+02  0.000000    21.333333
# 6685   3570  1158   0.155833  9.120000e+02  0.000833    15.166667
# 6686   3570  1175   0.150000  9.600000e+02  0.000000    17.750000
# 6687   3570  1187   0.146667  1.499000e+03  0.000000    14.666667
# 6688   3570  1199   0.211667  4.447225e+04  0.000000    14.916667
# 6689   3570  1215   0.030000  2.830000e+02  0.000000     7.500000
# 6690   3570  1232   0.113333  2.758667e+03  0.000000    15.666667
# 6691   3570  1246   0.159167  1.030242e+04  0.000833    15.000000
# 6692   3570  1266   0.168333  9.090150e+04  0.000833    22.750000
# 6693   3570  1286   0.231429  8.828429e+03  0.000000    13.428571
# 6694   3570  1293   0.093333  3.470000e+02  0.000000    10.666667
# 6695   3571  1019   0.000000  1.550000e+01  0.137143     2.500000
# 6696   3571  1038   0.120000  6.000000e+00  0.000000    17.000000
# 6697   3571  1159   0.232500  2.125852e+05  0.047500    15.250000
# 6698   3573  1019   0.208571  1.869286e+03  0.000714     5.285714
# 6699   3573  1038   0.000000  6.976667e+02  0.000000    15.333333
# 6700   3624  1123   0.000000  1.870000e+02  0.000000     3.000000
# 6701   3624  1172   0.160000  1.176400e+04  0.000000    15.750000
# 6702   3624  1212   0.145000  1.772000e+03  0.025000    24.000000
# 6703   3624  1245   0.190000  2.585000e+03  0.000000    29.000000
# 6704   3633  1201   0.238333  1.477850e+04  0.008333    22.500000
# 6705   3633  1238   0.225000  5.227333e+03  0.018333    21.333333
# 6706   3633  1289   0.214286  1.747214e+04  0.010000    28.000000
# 6707   3634  1204   0.220000  3.609000e+03  0.020000     9.000000
# 6708   3642  1286   0.050000  1.230000e+02  0.030000     5.000000
#
#        Linhas_Log  Qntd_Linhas_Filtrado  Nota  Submissoes     Testes
# 0       19.000000              9.000000   0.0    0.000000   1.000000
# 1      186.000000              5.500000   0.0    2.000000   6.000000
# 2      871.000000             20.000000   0.0    5.750000  20.500000
# 3      991.000000             20.000000   0.0   17.000000  42.000000
# 4       82.785714              2.071429   0.0    2.428571   1.214286
# 5      416.333333              6.166667   0.0    2.833333   6.416667
# 6      460.750000              6.833333   0.0    2.666667  13.166667
# 7      300.000000              5.666667   0.0    1.000000   3.000000
# 8      415.800000              8.600000   0.0    6.900000  13.300000
# 9       13.333333              8.333333   0.0    1.333333   3.333333
# 10     493.666667              9.666667   0.0    1.000000   8.666667
# 11     797.833333             21.916667   0.0   10.833333  24.000000
# 12    1455.500000             13.000000   0.0    4.500000  16.000000
# 13     891.333333             20.333333   0.0    1.666667  10.333333
# 14     481.083333              9.666667   0.0    2.750000   5.833333
# 15    1604.000000              9.333333   0.0   14.333333  67.666667
# 16     541.750000             13.166667   0.0    4.833333  12.583333
# 17    1214.000000             10.666667   0.0   31.333333  69.666667
# 18     308.272727             10.454545   0.0    1.636364   4.636364
# 19      99.200000             10.600000   0.0    1.200000   4.200000
# 20     949.666667             12.666667   0.0    2.333333  18.000000
# 21     208.250000             13.416667   0.0    1.416667   4.416667
# 22    1143.000000              9.333333   0.0    5.000000  44.000000
# 23      47.000000              3.000000   0.0    2.500000   2.000000
# 24      28.750000              1.000000   0.0    1.250000   2.250000
# 25      37.000000              2.000000   0.0    0.000000   0.000000
# 26     102.500000              2.071429   0.0    3.142857   3.000000
# 27     923.000000              6.333333   0.0    8.666667  13.083333
# 28     775.333333              7.000000   0.0    4.083333  31.000000
# 29     346.000000              4.666667   0.0    1.000000  13.000000
# ...           ...                   ...   ...         ...        ...
# 6679   733.400000              8.600000   0.0    3.100000  13.700000
# 6680   276.333333              8.500000   0.0    1.166667   4.666667
# 6681   527.666667             10.333333   0.0    1.666667   9.000000
# 6682  1810.833333             21.750000   0.0    3.916667  19.750000
# 6683   666.666667             16.000000   0.0    1.333333   5.333333
# 6684   746.666667             20.333333   0.0    1.333333   5.666667
# 6685   319.083333             10.583333   0.0    1.083333   5.916667
# 6686   616.500000             15.250000   0.0    1.000000   7.500000
# 6687   715.333333             12.666667   0.0    1.000000   9.333333
# 6688  1085.000000             13.500000   0.0    3.166667  20.750000
# 6689   170.500000              7.000000   0.0    0.500000   2.000000
# 6690   554.333333             15.333333   0.0    2.666667   7.000000
# 6691   583.083333             11.416667   0.0    1.083333   8.000000
# 6692  1023.166667             16.416667   0.0    5.166667  14.166667
# 6693   805.428571             11.857143   0.0    3.428571  14.571429
# 6694   378.666667             10.000000   0.0    1.666667   3.333333
# 6695     7.571429              1.928571   0.0    1.000000   1.000000
# 6696     8.000000              6.000000   0.0    0.000000   1.000000
# 6697   751.750000              9.750000   0.0    6.500000  40.750000
# 6698   200.571429              3.500000   0.0    1.642857   4.642857
# 6699    19.666667              5.000000   0.0    0.000000   0.666667
# 6700    18.000000              0.000000   0.0    0.000000   0.000000
# 6701  1145.000000             13.750000   0.0    0.500000  17.750000
# 6702  2502.000000             17.750000   0.0    1.500000  24.250000
# 6703  1933.000000             25.000000   0.0    0.000000  24.000000
# 6704   696.166667             15.333333   0.0   12.000000  45.333333
# 6705   820.166667             18.666667   0.0    5.166667  26.500000
# 6706   535.285714             17.714286   0.0    2.571429  18.285714
# 6707  1358.000000              8.000000   0.0   24.000000  68.000000
# 6708    98.000000              4.000000   0.0    2.000000   6.000000
#
# [6709 rows x 11 columns]

# %%
df.to_csv('dadosBrutos.csv', encoding='utf-8', index=False)
agrupado.to_csv('dadosPorLab.csv', encoding='utf-8', index=False)
agrupadoMedia.to_csv('dadosPorLabMean.csv', encoding='utf-8', index=False)

# %%
#df.loc[(df['coluna'] == 2) & (df['2'] == 4), 'coluna'] = 'novo valor'
