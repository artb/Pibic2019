# %% [markdown]
# Artigos pra ler: Student behaviour in unsuporvised online quizzzes : a closer look

# %% [raw]
# Coletor de atributos em cima dos logs do CodeBench

# %% [raw]
# Atributos coletados:
# DONE •attempts (M1): n de tentativas de submissao, independente se o codigo esta certo ou errado (AHADI; VIHAVAINEN; LISTER, 2016);
# • lloc (M4): media de numero de linhas logicas dos codigos submetidos, sem contabilizar importação de bibliotecas, comentários e linhas em branco (OTERO et al., 2016);
# • loc(M5):media de numero de linhas dos codigos submetidos(OTEROetal.,2016);
# • $$ system_access (M7): numero de acessos (logins) que cada aluno faz dentro do prazo de entrega de uma dada lista;
# • exam_grade_codebench (M8): nota na avaliacao realizada em cada sessao. (So vai ser usado nessa tabela)
# • delete_average (M10): media de caracteres apagados atraves do uso das teclas delete e backspace em cada lista de exercicios;
# • average_log_rows (M11): media do numero de linhas do log gerado por cada questao de uma dada lista de exercicios (CASTRO-WUNSCH; AHADI; PETERSEN, 2017; AHADI et al., 2015)4;
# • submission_per_exercise (M12): media de submissoes por exercicios, independente se o codigo estava certo ou errado.
# • sucess_average (M13): razao entre o numero de questoes corretamente avaliadas pelo numero de tentativas de submissao (AUVINEN, 2015; ESTEY; COADY, 2016);
# • test_average (M14): numero total de testes feitos durante as tentativas de solucionar todas as questões de uma lista dividido pelo numero total de questões da lista (ESTEY; COADY, 2016);
# • exercises_list_grade (M15): nota do aluno em cada lista de exercícios (AHADI; VIHAVAINEN; LISTER, 2016; CASTRO-WUNSCH; AHADI; PETERSEN, 2017; ESTEY; COADY, 2016);
# • exercises_list_grade_check_plagiarism (M16): nota do aluno em cada lista de exercícios, considerando apenas questões resolvidas que geraram no mínimo 50 linhas no log;
# • copy_paste_proportion (M17): proporção entre número de caracteres colados (com CTRL+V) e número caracteres digitados (MUNSON; ZITOVSKY, 2018);
# • sintaxe_error (M18): proporção entre o número total de submissões e o número total de submissões com erros de sintaxe (JADUD, 2006b; ESTEY; COADY, 2016; MUNSON; ZITOVSKY, 2018);
# IDE_usage (M19): tempo total (em minutos) que o aluno passa dentro do IDE tentando solucionar as questões de uma dada lista de exercícios, ou seja, digitando algo (AUVINEN, 2015; MUNSON; ZITOVSKY, 2018);
# • $$keystroke_latency (M20): velocidade de digitação de um dado aluno durante suas tentativas de solucionar as questões de uma dada lista de exercícios (LEINONEN et al., 2016);
# DONE • duration_of_exercices: diferença entre o tempo inicial e o tempo final
# • qnt_errors: quantidade de erros na submissao/execucao
# • had_syntax_error: binario se houve(1) ou nao(0) erro de sintaxe
# • qnt_blur: quantidade de vezes q houve um clique fora da IDE -posso fazer uma media de interacoes com mouse-
# • time_medio_ blur: tempo total da diferenca entre um blur e um focus dividido pelo tempo total do exercicio
# • average_interation_time: media de tempo de interacao usuario-sistema
# • (talvez) turno_realizado: turno do dia em que o exercicio foi terminado
# • $$hours_remaning_to_deadline: diferenca de horas desde o primeiro acesso ate o deadline do exercicio
# • n_acessos: quantidade de acessos em dias diferentes
# • media de exercicios por lab resolvidos (avg_participation) - somente a razao eh suficiente pra pesar o desempenho do aluno? -
# • (talvez) acumulado das razoes de exercicios
# • pesar os tipos erro (sintaxe e logica) e se o aluno colou associar a ele um valor menor

# %%
import re
import os
import math
import pandas as pd
import datetime

# %%
path = '/Volumes/MacOSExtended/Dataset/2018-1/'

# %% [markdown]
# cat database/2432/399_1326.log

# %%
dictHorarios = {}
colunasTabela = {'Aluno':['00'],
    'Laboratorio':['00'],
    'Exercicio':['00'],
    'Horario inicial':['00'],
    'Horario final':['00'],
    'Tempo decorrido':['00']
}

df2 = pd.DataFrame(columns=['oi','sa'])
print(df2)
# Out:
# Empty DataFrame
# Columns: [oi, sa]
# Index: []

# %%
#Coleta a data inicial e final de cada exercicio junto com o seu horario
def coletaDatas(arquivo):
    horarios = []
    hBegin = -1
    hEnd = -1
    dataIni = -1
    dataFim = -1
    horaIni = -1
    horaFim = -1
    for linha in arquivo:
        busca = re.findall(r'\d{4}-\d{1,2}-\d{1,2} \d+:\d+:\d+\.\d+',linha)
        if(len(busca) > 0):
            horaIni = busca[0]
            horarios.append(horaIni)
    if(len(horarios)>0):
        hBegin = horarios[0]
        hEnd = horarios[-1]
    if(hBegin != -1):
        busquinha = re.findall(r'\d{4}-\d{1,2}-\d{1,2}',hBegin)
        if(len(busquinha) > 0):
            dataIni = busquinha[0]
        busquinha = re.findall(r'\d+:\d+:\d+\.\d+',hBegin)
        if(len(busquinha) > 0):
            horaIni = busquinha[0]
    if(hEnd != -1):
            busquinha = re.findall(r'\d{4}-\d{1,2}-\d{1,2}',hEnd)
            if(len(busquinha)>0):
                    dataFim = busquinha[0]
            busquinha = re.findall(r'\d+:\d+:\d+\.\d+',hEnd)
            if(len(busquinha) > 0):
                horaFim = busquinha[0]
    '''            
    print("data raw:")
    print(hBegin,hEnd)
    print(dataIni, dataFim)
    print("Datas")
    print(horaIni,horaFim)
    print("EOF")
    '''
    return horarios, dataIni, dataFim, horaIni, horaFim

# %%
#Calcula a quantidade de linhas de um arquivo de log
def qntd_linhas_log(arquivo):
    contador = 0
    paste = 0
    delete = 0
    for linha in arquivo.split("\n"):
        contador += 1
        busca = re.search(r'paste',linha)
        busca2 = re.search(r'delete',linha)
        busca3 = re.search(r'Backspace',linha)
        if(busca): paste += 1
        if(busca2): delete += 1
        if(busca3): delete += 1
    
    p1 = paste/contador
    p2 = delete/contador
    return contador,round(p1,2),round(p2,2)

# %%
#Calcula o tempo empenhado no exercicio
def tempoEmpenhado(data_ini, data_fim, hora_ini, hora_fim):
    s = '' + str(data_ini) + ' ' + str(hora_ini) 
    r = '' + str(data_fim) + ' ' +str(hora_fim)
    date1 = int(datetime.datetime.strptime(s, '%Y-%m-%d %H:%M:%S.%f').strftime("%s"))
    date2 = int(datetime.datetime.strptime(r, '%Y-%m-%d %H:%M:%S.%f').strftime("%s"))
    difdate = date2 - date1
    return difdate

# %%
#Calcula a quantidade de dias em que o mesmo exercicio foi resolvido
def n_acessosColetor(arquivo):
    primeiroAcesso = 1
    difdate = 0
    for linha in arquivo:
        busca = re.search(r'\d{4}-\d{1,2}-\d{1,2}',linha)
        if(busca):
            if(primeiroAcesso):
                dataIni = busca.group(0)
                primeiroAcesso = 0
            dataAtual = busca.group(0)
            #date1 = int(datetime.datetime.strptime(dataIni, '%Y-%m-%d').strftime("%d"))
            #date2 = int(datetime.datetime.strptime(dataAtual, '%Y-%m-%d').strftime("%d"))
            #difdate = date2 - date1
            start_date = datetime.datetime.strptime(dataIni, '%Y-%m-%d')
            end_date = datetime.datetime.strptime(dataAtual, '%Y-%m-%d')
            difdate = abs(end_date-start_date)
            difdate = difdate.days
            

            
    
    return difdate

# %% [markdown]
# Funcoes na pasta Executions

# %%
#Ve a quantidade de submissoes em um exercicio
def attemptsColetor(arquivo):
    contador = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'SUBMITION',linha)
        if(busca): contador += 1
    return contador

# %%
#Ve a quantidade de testes em um exercicio
def testColetor(arquivo):
    contador = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'TEST',linha)
        if(busca): contador += 1
    return contador

# %% [markdown]
# Funcoes na pasta Scores

# %%
#Ve a quantidade de exercicios em um laboratorio
def exercicios_no_lab(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'number of exercises: \d+',linha)
        if(busca): 
            busca2 = re.search(r'\d+',busca.group(0))
            return busca2.group(0)

# %%
#Ve a quantidade de exercicios respondidos corretamente em um laboratorio
def exer_certos_no_lab(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'correct: \d+',linha)
        if(busca): 
            busca2 = re.search(r'\d+',busca.group(0))
            return busca2.group(0)

# %%
#Nota final por laboratorio
def nota_lab(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'final score  \(0-10\): \d+\.\d+',linha)
        if(busca):
            busca2 = re.search(r'\d+\.\d+',busca.group(0))
            return busca2.group(0)

# %%
#Quantidade de linhas de um codigo
def qntd_linhas(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'\w*',linha)
        if(busca): qntd += 1
    return qntd

# %%
#Quantidade de linhas de um codigo sem comentarios etc
def qntd_linhas_filtrado(arquivo):
    qntd = 0
    for linha in arquivo.split("\n"):
        busca = re.search(r'\S',linha)
        if(busca): 
            busca2 = re.search(r'^(?!#).*',busca.group(0))
            if(busca2): qntd += 1

    return qntd

# %%
def keystroke_latency(arquivo):
    for linha in arquivo.split("\n"):
        hora = re.search(r'\d{4}-\d{1,2}-\d{1,2}',linha)

# %% [raw]
# Main Function

# %%
#Definindo o DataFrame
colunas = ['Aluno','Lab','Exercicio','Duracao','Qntd_Linhas','Qntd_Linhas_Filtrado','Testes','Submissoes','N_Dias','PP_Paste','PP_Delete','Linhas_Log','Nota']
df = pd.DataFrame(columns = colunas)
print(df)
df = df[0:0]
# Out:
# Empty DataFrame
# Columns: [Aluno, Lab, Exercicio, Duracao, Qntd_Linhas, Qntd_Linhas_Filtrado, Testes, Submissoes, N_Dias, PP_Paste, PP_Delete, Linhas_Log, Nota]
# Index: []

# %%
#MAIN
for folder in os.listdir(path):
    if not folder.startswith('.'):
        
        directory = os.path.join(path,folder)+'/users/'
        classe = folder
        for aux in os.listdir(directory):
            print(directory,aux)
            #directory = os.path.join(directory,aux)
            #pastaLogs = directory + aux + '/codemirror'
            pastaLogs = os.path.join(directory,aux) + '/codemirror'
            #Trabalhando com o arquivo do logs de interacao
            aluno = aux
            for file in os.listdir(pastaLogs):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]
                    exercicio = buscaL[1]
                file = os.path.join(pastaLogs,file)
                arquivo = open(file,'r',encoding='ISO-8859-1')
                data = arquivo.read()
                dataSplitado = data.split("\n")
                #-/-
                #parte para coleta de horario
                vetHorarios, date_begin, date_end, hour_begin, hour_end = coletaDatas(dataSplitado)
                dictHorarios[str(exercicio)] = vetHorarios

                if(hour_begin != -1):
                    #calcula o tempo emepnhado
                    exr_duration = tempoEmpenhado(date_begin, date_end, hour_begin, hour_end)
                #Coleta numero de acessos
                n_acessos = n_acessosColetor(dataSplitado)
                if(n_acessos == 0): n_acessos = 1
                qt_linhas, pp_paste, pp_delete = qntd_linhas_log(data)
                df = df.append({'Aluno': aluno,'Lab' : laboratorio,'Exercicio' : exercicio,'Duracao':exr_duration
                                ,'Qntd_Linhas':0,'Qntd_Linhas_Filtrado':0,'Testes':0,'Submissoes':0,'N_Dias':n_acessos,
                                'PP_Paste':pp_paste,'PP_Delete':pp_delete,'Linhas_Log':qt_linhas,'Nota':0.0}, ignore_index=True)    


            #a partir de agora eu trabalho com outro tipo de arquivo para a coleta, o de tests e submissions
            pastaExecucoes = os.path.join(directory,aux) + '/executions'
            for file in os.listdir(pastaExecucoes):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]
                    exercicio = buscaL[1]  
                file = os.path.join(pastaExecucoes,file)
                arquivo = open(file,'r',encoding='ISO-8859-1')
                data = arquivo.read()
                #Quantidade de submissoes por exercicio
                attempts = attemptsColetor(data)

                #Quantidade de testes por exercicio
                tests = testColetor(data)
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Testes'] = tests
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Submissoes'] = attempts

            #Coletando atributos da pasta score 
            pastaScores = os.path.join(directory,aux) + '/grades'
            for file in os.listdir(pastaScores):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]  
                #file = os.path.join(pastaScores,file)
                #arquivo = open(file,'r',encoding='ISO-8859-1')
                #data = arquivo.read()
                #Quantidade de exercicios do laboratorio
                #qntd_exercicios = exercicios_no_lab(data)
                #Quantidade de exercicios do laboratorio respondidos corretamente
                #qntd_exer_corretos = exer_certos_no_lab(data)
                #Nota do lab
                #nota_do_lab = nota_lab((data))
                #if(nota_do_lab == None): nota_do_lab = 0
                #df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio),'Nota'] = float(nota_do_lab)
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio),'Nota'] = 0

            #Coletando atributos da pasta codes
            pastaCodigos = os.path.join(directory,aux) + '/codes'
            for file in os.listdir(pastaCodigos):
                buscaL = re.findall(r'\d+',file)
                if(len(buscaL) > 0):
                    laboratorio = buscaL[0]
                    exercicio = buscaL[1]  
                file = os.path.join(pastaCodigos,file)
                arquivo = open(file,'r',encoding='ISO-8859-1')
                data = arquivo.read()
                #Quantidade de linhas de um codigo
                linhas_codigo = qntd_linhas(data)
                #Quantidade de linhas de um codigo sem comentarios, importacoes
                linhas_codigo_filtrado = qntd_linhas_filtrado(data)
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Qntd_Linhas'] = linhas_codigo
                df.loc[(df['Aluno'] == aluno) & (df['Lab'] == laboratorio) & (df['Exercicio'] == exercicio)
                       ,'Qntd_Linhas_Filtrado'] = linhas_codigo_filtrado
# Out:
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 1173
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 1305
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 1310
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 1688
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 1984
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2101
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2102
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2103
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2104
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2105
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2107
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2108
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2109
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2110
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2111
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2112
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2113
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2114
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2115
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2116
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2117
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2118
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2119
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2120
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2121
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2122
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2123
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2124
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2125
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2126
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2127
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2128
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2129
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2130
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2131
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2132
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2133
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2134
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2338
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2340
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2341
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2342
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2343
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2344
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2345
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2346
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2367
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2403
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2477
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2478
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2479
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2506
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2546
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2552
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2578
# /Volumes/MacOSExtended/Dataset/2017-1/135/users/ 2634
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1098
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1099
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1191
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1206
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1237
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1265
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1428
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1439
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1590
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1892
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1894
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1897
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1898
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1907
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1925
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1939
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 1986
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2008
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2010
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2020
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2101
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2135
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2136
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 2137
# /Volumes/MacOSExtended/Dataset/2017-1/136/users/ 
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2275
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2277
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2278
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2279
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2329
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2421
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2422
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2423
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2424
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2532
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2533
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2534
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2564
# /Volumes/MacOSExtended/Dataset/2017-1/143/users/ 2587
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1236
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1242
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1267
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1294
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1304
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1466
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1567
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1677
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1686
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1719
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1766
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1772
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1901
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1915
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1921
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1925
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 1930
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2192
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2196
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2197
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2198
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2199
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2202
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2203
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2204
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2371
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2376
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2415
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2510
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2511
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2554
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2556
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2580
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2581
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2600
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2616
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2631
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2682
# /Volumes/MacOSExtended/Dataset/2017-1/144/users/ 2779

# %%
print("aluno:",aluno)
print("Dia inicio:",date_begin, "Dia fim:",date_end, "Hora inicio:",hour_begin,"Hora fim:", hour_end)
print("Numero de dias empenhados durante exercicio:",n_acessos)
print("Tempo empenhado na atividade em segundos:",exr_duration)
print("Numero do lab:",laboratorio,"exercicio:",exercicio,"submissoes:",attempts,"testes:",tests)
print("Nota:",nota_do_lab)
print("Quantidade de linhas de codigo:",linhas_codigo, "Quantidade de linhas de codigo sem comentarios/importacoes:",linhas_codigo_filtrado)
# Out:
# aluno: 2779
# Dia inicio: 2017-7-10 Dia fim: 2017-7-10 Hora inicio: 02:11:04.687 Hora fim: 02:25:56.319
# Numero de dias empenhados durante exercicio: 1
# Tempo empenhado na atividade em segundos: 892
# Numero do lab: 536 exercicio: 1101 submissoes: 11 testes: 35
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e2d6490a975d> in <module>()
#       4 print("Tempo empenhado na atividade em segundos:",exr_duration)
#       5 print("Numero do lab:",laboratorio,"exercicio:",exercicio,"submissoes:",attempts,"testes:",tests)
# ----> 6 print("Nota:",nota_do_lab)
#       7 print("Quantidade de linhas de codigo:",linhas_codigo, "Quantidade de linhas de codigo sem comentarios/importacoes:",linhas_codigo_filtrado)
#
# NameError: name 'nota_do_lab' is not defined

# %%
df['Aluno'] = df['Aluno'].astype(int)
df['Lab'] = df['Lab'].astype(int)
df['Duracao'] = df['Duracao'].astype(int)
df['Qntd_Linhas'] = df['Qntd_Linhas'].astype(int)
df['Qntd_Linhas_Filtrado'] = df['Qntd_Linhas_Filtrado'].astype(int)
df['Testes'] = df['Testes'].astype(int)
df['Submissoes'] = df['Submissoes'].astype(int)
df['N_Dias'] = df['N_Dias'].astype(int)
df['PP_Paste'] = df['PP_Paste'].astype(float)
df['PP_Delete'] = df['PP_Delete'].astype(float)
df['Linhas_Log'] = df['Linhas_Log'].astype(int)
df['Nota'] = df['Nota'].astype(float)

# %%
#Porcentagem de exercicios corretos/ total execicios por lab

# %%
agrupado =  df.groupby(['Aluno','Lab'],as_index=False).agg({'Duracao': 'sum', 'Qntd_Linhas': 'sum', 'Qntd_Linhas_Filtrado': 'sum'
                                             , 'Testes': 'sum', 'Submissoes': 'sum', 'PP_Paste': 'sum'
                                             , 'PP_Delete': 'sum', 'Linhas_Log': 'sum', 'Nota':'mean'})

# %%
agrupado
# Out:
#       Aluno  Lab  Duracao  Qntd_Linhas  Qntd_Linhas_Filtrado  Testes  \
# 0      1085  437     3373           37                    23      19
# 1      1085  457       68            3                     3       1
# 2      1098  407  1318194           43                    36      74
# 3      1098  455   933350          167                    80      66
# 4      1098  456    25947           72                    47      89
# 5      1098  474     1539           20                    14      20
# 25             5      0.00       0.44        1399   0.0
# 26            81      0.03       1.80       10175   0.0
# 27            18      0.04       1.24        4931   0.0
# 28             6      0.00       0.54        2742   0.0
# 29             7      0.34       1.17        1990   0.0
# ...          ...       ...        ...         ...   ...
# 6310           0      0.00       0.29         518   0.0
# 6311           9      0.01       0.54        1886   0.0
# 6312           0      0.00       0.20         275   0.0
# 6313           0      0.00       0.96        1667   0.0
# 6314          69      0.03       3.31       10736   0.0
# 6315           0      0.00       0.65        1016   0.0
# 6316          11      0.00       0.40         676   0.0
# 6317          16      0.23       3.89        1710   0.0
# 6318           0      0.00       0.00          13   0.0
# 6319           2      0.01       0.45        1269   0.0
# 6320          57      0.02       4.27       11712   0.0
# 6321           0      0.00       0.50          16   0.0
# 6322          16      0.01       0.55        1788   0.0
# 6323           0      0.00       1.25        1401   0.0
# 6324           0      0.01       0.45        1616   0.0
# 6325           0      0.00       0.65         249   0.0
# 6326           0      0.00       0.28         552   0.0
# 6327          13      1.10       1.83         693   0.0
# 6328           0      0.01       0.65         504   0.0
# 6329          10      1.49       0.62         362   0.0
# 6330           1      0.00       0.00          34   0.0
# 6331          17      0.66       1.27         543   0.0
# 6332           7      1.36       0.00          61   0.0
# 6333          12      2.20       0.42         121   0.0
# 6334          11      1.82       0.07         120   0.0
# 6335           6      1.23       0.00          59   0.0
# 6336           9      1.58       0.31         267   0.0
# 6337          16      0.00       2.56        1238   0.0
# 6338           0      0.00       0.00           2   0.0
# 6339          52      0.05       1.16        3010   0.0
#
# [6340 rows x 11 columns]

# %%
agrupadoMedia = df.groupby(['Aluno','Lab'],as_index=False).agg({'Duracao': 'mean', 'Qntd_Linhas': 'mean', 'Qntd_Linhas_Filtrado': 'mean'
                                             , 'Testes': 'mean', 'Submissoes': 'mean', 'PP_Paste': 'mean'
                                             , 'PP_Delete': 'mean', 'Linhas_Log': 'mean', 'Nota':'mean'})

# %% [markdown]
# print(agrupadoMedia)

# %%
agrupadoMedia
# Out:
#       Aluno  Lab        Duracao  Qntd_Linhas  Qntd_Linhas_Filtrado     Testes  \
# 0      1085  437     843.250000     9.250000              5.750000   4.750000
# 1      1085  457      68.000000     3.000000              3.000000   1.000000
# 2      1098  407   94156.714286     3.071429              2.571429   5.285714
# 3      1098  455   77779.166667    13.916667              6.666667   5.500000
# 4      1098  456    3706.714286    10.285714              6.714286  12.714286
# 5      1098  474     769.500000    10.000000              7.000000  10.000000
# 6      1098  493  221749.000000    14.555556              8.555556  14.333333
# 7      1098  494      15.666667    15.833333             12.500000   3.166667
# 8      1098  523    3081.500000    15.500000             11.000000  12.500000
# 9      1098  533      21.166667    21.500000             17.000000   3.000000
# 10     1098  534  100991.555556    24.333333             18.666667  10.222222
# 11     1098  569    2206.000000    17.000000             14.500000  25.500000
# 12     1098  587   89191.750000    15.500000             10.166667   9.416667
# 13     1098  621    1741.000000    12.500000              5.500000  15.500000
# 14     1098  630   68417.363636    15.363636             13.727273   4.636364
# 15     1098  659     523.000000    15.000000             11.200000   8.400000
# 16     1098  671    2160.500000    11.500000              8.500000  16.500000
# 17     1098  693   97798.700000    17.200000             11.700000   5.700000
# 18     1098  694      38.600000    14.800000             10.600000   4.000000
# 11      6.000000  0.010000   0.195000   983.000000   0.0
# 12      2.166667  0.108333   0.163333   215.166667   0.0
# 13      0.500000  0.005000   0.110000   615.500000   0.0
# 14      1.363636  0.152727   0.060909    50.272727   0.0
# 15      1.800000  0.066000   0.174000   200.000000   0.0
# 16      1.000000  0.005000   0.370000   875.500000   0.0
# 17      1.100000  0.157000   0.067000    44.000000   0.0
# 18      1.600000  0.150000   0.062000    15.000000   0.0
# 19      0.000000  0.015000   0.235000   413.000000   0.0
# 20      1.300000  0.104000   0.183000   172.100000   0.0
# 21      2.000000  0.015000   0.410000   343.500000   0.0
# 22      1.571429  0.028571   0.155714   111.285714   0.0
# 23      1.666667  0.017500   0.238333   436.916667   0.0
# 24      1.142857  0.037143   0.162857   158.714286   0.0
# 25      2.500000  0.000000   0.220000   699.500000   0.0
# 26      9.000000  0.003333   0.200000  1130.555556   0.0
# 27      3.000000  0.006667   0.206667   821.833333   0.0
# 28      3.000000  0.000000   0.270000  1371.000000   0.0
# 29      1.166667  0.056667   0.195000   331.666667   0.0
# ...          ...       ...        ...          ...   ...
# 6310    0.000000  0.000000   0.290000   518.000000   0.0
# 6311    4.500000  0.005000   0.270000   943.000000   0.0
# 6312    0.000000  0.000000   0.200000   275.000000   0.0
# 6313    0.000000  0.000000   0.320000   555.666667   0.0
# 6314    6.272727  0.002727   0.300909   976.000000   0.0
# 6315    0.000000  0.000000   0.325000   508.000000   0.0
# 6316    5.500000  0.000000   0.200000   338.000000   0.0
# 6317    1.142857  0.016429   0.277857   122.142857   0.0
# 6318    0.000000  0.000000   0.000000    13.000000   0.0
# 6319    0.666667  0.003333   0.150000   423.000000   0.0
# 6320    6.333333  0.002222   0.474444  1301.333333   0.0
# 6321    0.000000  0.000000   0.500000    16.000000   0.0
# 6322    8.000000  0.005000   0.275000   894.000000   0.0
# 6323    0.000000  0.000000   0.625000   700.500000   0.0
# 6324    0.000000  0.005000   0.225000   808.000000   0.0
# 6325    0.000000  0.000000   0.325000   124.500000   0.0
# 6326    0.000000  0.000000   0.140000   276.000000   0.0
# 6327    1.181818  0.100000   0.166364    63.000000   0.0
# 6328    0.000000  0.005000   0.325000   252.000000   0.0
# 6329    1.000000  0.149000   0.062000    36.200000   0.0
# 6330    1.000000  0.000000   0.000000    34.000000   0.0
# 6331    1.214286  0.047143   0.090714    38.785714   0.0
# 6332    1.000000  0.194286   0.000000     8.714286   0.0
# 6333    1.000000  0.183333   0.035000    10.083333   0.0
# 6334    1.222222  0.202222   0.007778    13.333333   0.0
# 6335    1.000000  0.205000   0.000000     9.833333   0.0
# 6336    1.000000  0.175556   0.034444    29.666667   0.0
# 6337    1.142857  0.000000   0.182857    88.428571   0.0
# 6338    0.000000  0.000000   0.000000     2.000000   0.0
# 6339   13.000000  0.012500   0.290000   752.500000   0.0
#
# [6340 rows x 11 columns]

# %%
df.to_csv('dadosBrutos.csv', encoding='utf-8', index=False)
agrupado.to_csv('dadosPorLab.csv', encoding='utf-8', index=False)
agrupadoMedia.to_csv('dadosLab2018.csv', encoding='utf-8', index=False)

# %%
#df.loc[(df['coluna'] == 2) & (df['2'] == 4), 'coluna'] = 'novo valor'
